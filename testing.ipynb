# %% [markdown]
# Mikes Magic Import Incantation

# %%
from __future__ import print_function, division

import numpy as np
import nilearn
import matplotlib as mpl
import matplotlib.pyplot as plt
# %pylab inline

import pandas as pd

import nibabel

from nilearn import plotting

import csv

import os

from IPython.display import Image
from IPython.display import Markdown
from IPython.display import display

# %load_ext rpy2.ipython
import rpy2
import rpy2.robjects as robjects
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
import os
import sys
import re
from threading import Thread
from collect_raw_data.collect_raw_data import init_fmri_subject_dir, download_raw_fmri_data
from preprocessing.PreMelodicProcessing import Preprocessing
from preprocessing.StructuralProcessing import StructuralProcessing
from preprocessing.Melodic import Melodic
from preprocessing.PostMelodicProcessing import PostMelodic
from connectome_analyses.FunctionalConnectivity import FunctionalConnectome


class PreprocessingPipeline:
    """ Wraps a subject in the entire preprocessing pipeline
        
        Allows for parellelization and easy management of which
        stages of preprocessing are used
    """

    def __init__(self, subject_list, phase):
        self.subject_list = subject_list
        self.phase = phase.lower()

    def pipeline(self):
        """ Monolithic method that contains the entire preprocessing pipeline

            Stages of preprocessing are specified via command line args:
                Premelodic - initial preprocessing steps on time series,
                             including volume removal, slicetime correction,
                             motion correction, distortion correction,
                             registration into T1 space, etc.
                Melodic - independent component analysis across time series;
                          as of now, hand denoising MUST be done after this step
                Postmelodic - Removal of noise components, spatial smoothing,
                          masking of confounds, and generation of 
                          functional connectome for each subject
        """

        for subjectID in self.subject_list:
            if re.search('[0-9]', subjectID):
                subjectID = check_prefix(subjectID)
                subjectID = subjectID.strip()
            else:
                continue

            # docker container can't see QSM repo, so can't check from notebook
#             if starting_files_present(subjectID) == False:
#                 print("Skipping {}, not all files present".format(subjectID))
#                 continue
#             else:
#                 print(subjectID)

            try:
                if self.phase == "melodic":
                    processing = Preprocessing(subjectID)
                    melodic = Melodic(processing)

                    melodic.init_melodic_directory()
                    melodic.ICA()

                elif self.phase == "postmelodic":
                    processing = Preprocessing(subjectID)
                    postmel = PostMelodic(processing)
                    structproc = StructuralProcessing(processing)
                    fcon = FunctionalConnectome(subjectID)

                    postmel.denoise()
                    structproc.gm_mask()
                    structproc.csf_mask()
                    structproc.wm_mask()
                    structproc.binarize_masks()
                    postmel.mask_mean_time_series()
                    postmel.create_all_confounds()
                    fcon.create_functional_connectivity_matrix()

                elif self.phase == "premelodic":
                    init_fmri_subject_dir(subjectID,
                                          "/shared/studies/nonregulated/connectome/fmri/subjects/",
                                          "/shared/studies/nonregulated/connectome/Subjects/" + subjectID + "/T1w/")

                    processing = Preprocessing(subjectID)
                    structproc = StructuralProcessing(processing)

                    processing.remove_first_two_volumes()
                    processing.slicetime_correction()
                    processing.motion_correction()
                    processing.intensity_normalization()
                    processing.temporal_mean()
                    processing.temporal_filtering()
                    processing.brain_extraction()
                    processing.epi_distortion_correction()
                    processing.zero_center_fieldmap()

                    structproc.generate_aparcaseg()
                    structproc.downsize_T1()

                    processing.ANTs_registration()
                    processing.motion_outlier_detection()
                    processing.spatial_smoothing()

                elif self.phase == "all":
                    init_fmri_subject_dir(subjectID,
                                          "/shared/studies/nonregulated/connectome/fmri/subjects/",
                                          "/shared/studies/nonregulated/connectome/Subjects/" + subjectID + "/T1w/")

                    processing = Preprocessing(subjectID)
                    structproc = StructuralProcessing(processing)
                    # melodic = Melodic(processing)
                    postmel = PostMelodic(processing)

                    processing.remove_first_two_volumes()
                    processing.slicetime_correction()
                    processing.motion_correction()
                    processing.intensity_normalization()
                    processing.temporal_mean()
                    processing.temporal_filtering()
                    processing.brain_extraction()
                    processing.epi_distortion_correction()
                    processing.zero_center_fieldmap()

                    structproc.generate_aparcaseg()
                    structproc.downsize_T1()
                    
                    processing.ANTs_registration()
                    processing.motion_outlier_detection()
                    processing.spatial_smoothing()
                    
                    melodic.init_melodic_directory()
                    melodic.ICA()
                    postmel.denoise()

                    structproc.gm_mask()
                    structproc.csf_mask()
                    structproc.wm_mask()
                    structproc.binarize_masks()

                    postmel.mask_mean_time_series()
                    postmel.create_all_confounds()
                    
                else:
                    processing = Preprocessing(subjectID)
                    fcon = FunctionalConnectome(subjectID)
                    fcon.create_functional_connectivity_matrix()

            except:
                print("{}: Something went wrong".format(subjectID))
                pass

#             break


def starting_files_present(subjectID):
    """ Verify that each subject has:
            Fully processed strucutral image (T1 freesurfer output)
            Unprocessed raw functional image from bluesky
            QSM fieldmap images (magnitude and phase images)
        before beginning processing
    """

    path_conntectome = "/shared/studies/nonregulated/connectome/"
    functional_data = path_conntectome + "fmri/subjects/" + subjectID + "/rawfunc.nii.gz"
    structural_data = path_conntectome + "Subjects/" + subjectID + "/T1w/T1w_acpc_dc_restore_brain.nii.gz"
    QSM_path = "/shared/studies/nonregulated/qsm_repo/data/" + subjectID.replace("EX","") + "/recon/"

    if (not os.path.exists(functional_data)
            or not os.path.exists(structural_data)
            or not os.path.exists(QSM_path + "magnitude_combined.nii.gz")
            or not os.path.exists(QSM_path + "phase_combined.nii.gz")):
        return False
    else:
        return True


def check_prefix(subject):
    """ Append 'EX' to subject's ID if necessary
    """

    if "EX" not in subject:
        subject = "EX" + subject

    return subject


def create_threads(full_subject_list, num_threads):
    """ Split the input subject list into a specified number of sublists
        to parellelize the preprocessing pipeline up to 8 times
    """

    for i in range(0, len(full_subject_list), num_threads):
        yield(full_subject_list[i:i + num_threads])


if __name__ == "__main__":

    # Read in subject list from command line argument
#     with open(sys.argv[1]) as infile:
#         full_subject_list = infile.read().splitlines()
    with open('missing_subs.txt') as infile:
        full_subject_list = infile.read().splitlines()

#     phase = sys.argv[2]
    phase = "something else"
    print(phase)
    preproc = PreprocessingPipeline(full_subject_list, phase)
    preproc.pipeline()

    # Split up list into specified number of sublists and run in parellel
#     num_threads = int(sys.argv[2])
#     phase = sys.argv[3]
#     num_threads = 10
#     phase = "something else"

#     for thread in create_threads(full_subject_list, num_threads):
#        preproc = PreprocessingPipeline(thread, phase)
#        thread_process = Thread(target = preproc.pipeline)
#        thread_process.start()
# Out:
# something else
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX82576/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX82576//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803a610>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094b50>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX82576//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX82576//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.0s, 0.2min
# Fit time series
# Generated connectivity matrix
# /usr/local/lib/python2.7/dist-packages/numpy/linalg/linalg.py:1965: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX55777/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX55777//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037cb2a90>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094cd0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX55777//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX55777//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# /usr/lib/python2.7/dist-packages/sklearn/covariance/graph_lasso_.py:230: RuntimeWarning: invalid value encountered in multiply
#   * coefs)
# /usr/lib/python2.7/dist-packages/sklearn/covariance/graph_lasso_.py:232: RuntimeWarning: invalid value encountered in multiply
#   * coefs)
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX85303/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX85303//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c60a50>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094a90>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX85303//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX85303//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.9s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX54630/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX54630//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037caaa50>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094990>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX54630//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX54630//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:36: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial)
# Generated SIC matrix
# EX57125: Something went wrong
# EX71318: Something went wrong
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84414/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84414//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803ab10>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094a10>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84414//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84414//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.1s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84326/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84326//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037caaf10>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094b90>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84326//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84326//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.9s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX85275/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX85275//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c60b90>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037caafd0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX85275//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX85275//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.1s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX55832/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX55832//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c51190>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037caaa50>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX55832//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX55832//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# EX56881: Something went wrong
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX80483/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX80483//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803ae10>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c51050>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX80483//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX80483//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.9s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# EX57485: Something went wrong
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84712/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84712//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037caabd0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f60380944d0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84712//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84712//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.6s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# EX71386: Something went wrong
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX79565/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX79565//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037cb2c90>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c51310>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX79565//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX79565//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.0s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX56908/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX56908//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c51850>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c51ad0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX56908//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX56908//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.0s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# EX57484: Something went wrong
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX55513/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX55513//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037cb2610>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c85250>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX55513//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX55513//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# EX72964: Something went wrong
# EX84311: Something went wrong
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84826/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84826//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c60bd0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f60380944d0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84826//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84826//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX82040/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX82040//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037caa9d0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094d50>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX82040//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX82040//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.2s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX82193/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX82193//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c51110>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094bd0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX82193//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX82193//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.1s, 0.2min
# Fit time series
# Generated connectivity matrix
# /usr/lib/python2.7/dist-packages/sklearn/covariance/graph_lasso_.py:252: ConvergenceWarning: graph_lasso: did not converge after 100 iteration: dual gap: -6.201e-04
#   ConvergenceWarning)
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX81387/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX81387//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803a810>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094ad0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX81387//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX81387//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.7s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX80701/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX80701//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c51650>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094bd0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX80701//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX80701//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.9s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX80654/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX80654//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c60a90>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094990>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX80654//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX80654//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.0s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84284/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84284//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037cb2510>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c51190>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84284//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84284//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.9s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84559/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84559//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803a110>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c609d0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84559//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84559//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.0s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX80280/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX80280//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c51650>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037cb2fd0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX80280//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX80280//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.9s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX85312/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX85312//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037caaf90>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037cb2150>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX85312//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX85312//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.7s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX85050/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX85050//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c85110>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037cb29d0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX85050//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX85050//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.0s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84513/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84513//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803a550>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c85490>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84513//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84513//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.0s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX80873/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX80873//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037cb2890>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c85190>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX80873//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX80873//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84296/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84296//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037caa8d0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c852d0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84296//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84296//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.1s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# EX78339: Something went wrong
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX82315/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX82315//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c60c90>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c854d0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX82315//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX82315//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# EX84969: Something went wrong
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX79097/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX79097//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803add0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c85250>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX79097//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX79097//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84886/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84886//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c51150>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c85510>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84886//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84886//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX83541/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX83541//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037caa9d0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f603803a350>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX83541//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX83541//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.7s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX73902/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX73902//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037cb29d0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c854d0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX73902//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX73902//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# /usr/lib/python2.7/dist-packages/sklearn/covariance/graph_lasso_.py:252: ConvergenceWarning: graph_lasso: did not converge after 100 iteration: dual gap: -7.472e-04
#   ConvergenceWarning)
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX82165/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX82165//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803af90>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037caaed0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
# ...
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84791//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c51b50>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037caaa10>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84791//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84791//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.7s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84790/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84790//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803a850>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c51450>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84790//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84790//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.7s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# EX85404: Something went wrong
# EX85401: Something went wrong
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX85400/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX85400//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037caa990>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c51750>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX85400//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX85400//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX85402/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX85402//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c60a50>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c515d0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX85402//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX85402//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84763/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84763//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037cb2950>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c51090>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84763//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84763//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX80816/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX80816//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c60b90>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c51410>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX80816//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX80816//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.8s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX83437/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX83437//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037cb2bd0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c60f50>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX83437//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX83437//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.1s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX85302/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX85302//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c857d0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c60bd0>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX85302//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX85302//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.0s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84068/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84068//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f603803aad0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6037c60a90>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84068//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84068//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 2.7s, 0.0min
# Fit time series
# Generated connectivity matrix
# /usr/lib/python2.7/dist-packages/sklearn/covariance/graph_lasso_.py:252: ConvergenceWarning: graph_lasso: did not converge after 100 iteration: dual gap: -3.107e-03
#   ConvergenceWarning)
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84143/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84143//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6038094b90>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094b50>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84143//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84143//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 12.2s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# Loaded images
# [NiftiLabelsMasker.fit_transform] loading data from Nifti1Image('/shared/studies/nonregulated/connectome/Subjects/EX84598/T1w/GMmask_2.00.nii.gz')
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/shared/studies/nonregulated/connectome/fmri/subjects/EX84598//denoise.ica/Denoised_data.nii.gz',
# <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f6037c51a50>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x7f6038094990>,
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/shared/studies/nonregulated/connectome/fmri/subjects/EX84598//spreadsheets/all_confounds.csv', memory_level=1, verbose=5, memory=Memory(cachedir='nilearn_cache/joblib'))
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /shared/studies/nonregulated/connectome/fmri/subjects/EX84598//denoise.ica/Denoised_data.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ______________________________________________filter_and_extract - 11.9s, 0.2min
# Fit time series
# Generated connectivity matrix
# Generated SIC matrix
# /usr/lib/python2.7/dist-packages/sklearn/covariance/graph_lasso_.py:252: ConvergenceWarning: graph_lasso: did not converge after 100 iteration: dual gap: -2.099e-04
#   ConvergenceWarning)
